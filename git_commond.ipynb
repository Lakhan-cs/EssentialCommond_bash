# %% [markdown]
# # All basic essential git commonds :

# %% [markdown]
# ### After intallation process

# %%
"""git config --global user.name "Your Name"
git config --global user.email 
git cofig --list """

#ls -> for all details of files and folders
#ls-a -> for all hidden files and folders
#pwd -> present working file path
#cd -> run in specific file path
#cd .. -> to go back one folder/file
print("These are some basic git commands")
# Out:
# These are some basic git commands

# %% [markdown]
# ### Upload any local file on Github via vs terminal  🌟✨🌟

# %%
### open file , pdf, dataset, code in vs code
print("make new repo in git with README.md , now private can be public future")
print("copy the link of the repository from github in https")

### open terminal in any folder (cd folder) --> git bash
#git clone "link"               ### it will add the repo in folder
print("use Tab for auto completion of anything also in python")

#cd "name of repo"\
print("now we can modify repo by add/drag some other file in repo_folder edit text , dataset, pdf, image, python code ....")
#print("git status -> to check the status of the files modified/added/deleted")
#git add . - add all modified files
#git commit -m "message" - saved all changes with message
#git push origin main - upload all changes and files to github
#git pull   - upload all github changes in local
#cd .. - exiest from the folder
# Out:
# make new repo in git with README.md , now private can be public future
# copy the link of the repository from github in https
# use Tab for auto completion of anything also in python
# now we can modify repo by add/drag some other file in repo_folder edit text , dataset, pdf, image, python code ....

# %% [markdown]
# ### Modify the repo of G.H. by adding new folder , file in them

# %%
#mkdir folder name - create new folder
#rkdir folder name - delete folder
#cd folder name - enter into folder
#git init - initialize git in the folder
print("now we can modify and add new files like .py, .css, .html in folder")


print("To upload this folder in github ... create new repo in git without README.md file")
print("cpoy the new repo link")
#git remote add origin "link" --- in vscode 
#git remote -v --- for varify 
#git branch  #git branch -M main
#git push -u origin main -----> after this git push in fut.
print("now all changes will be uploaded to github repo")
# Out:
# now we can modify and add new files like .py, .css, .html in folder
# To upload this folder in github ... create new repo in git without README.md file
# cpoy the new repo link
# now all changes will be uploaded to github repo

# %% [markdown]
# ### Branch commonds

# %%
# git checkout -b "branch1" -> to create new branch and switch to it
# git branch
# git checkout "branch2" -> to switch to existing branch
# git branch -d "branch1" -> to delete branch1

""" WE will get two branches after push , add and commit but which branch we will push 
has copied main branch repo but it also have new changes commits """


# git diff branchname --- it will show the difference between two branches
# git merge branchname --- it will merge the changes of branchname to current branch

# git pull origin main --- it will pull the changes from remote main branch to local current branch

# git pull origin main --- it will pull the changes from remote repo to local repo
""" Using these cmd I got my saved master commits in main (local) from github (remote) """
# Out:
# ' Using these cmd I got my saved master commits in main (local) from github (remote) '
